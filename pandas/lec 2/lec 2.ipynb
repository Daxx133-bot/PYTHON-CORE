# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_excel("IPL.xls")
df.head()
# Out:
#    Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0             1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1             2  League Match  Apr 19  2008     Mohali            Chennai
# 2             3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3             4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4             5  League Match  Apr 20  2008     Mumbai             Mumbai
#
#   Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0           Bangalore                    222                       3
# 1              Punjab                    240                       5
# 2               Delhi                    129                       8
# 3             Kolkata                    110                      10
# 4           Bangalore                    165                       6
#
#    Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Match_Number                514 non-null    int64
#  1   Match                       514 non-null    object
#  2   Date                        514 non-null    object
#  3   Year                        514 non-null    int64
#  4   Venue                       514 non-null    object
#  5   Team_Batting_First          514 non-null    object
#  6   Team_Batting_Second         514 non-null    object
#  7   Bat_First_Runs_Scored       514 non-null    int64
#  8   Bat_First_Wickets_Lost      514 non-null    int64
#  9   Bat_First_Overs_Consumed    514 non-null    float64
#  10  Bat_First_Overs_Allocated   514 non-null    int64
#  11  Bat_Second_Runs_Scored      514 non-null    int64
#  12  Bat_Second_Wickets_Lost     514 non-null    int64
# ...

# %%
df.groupby("Year").size()
# Out:
# Year
# 2008    58
# 2009    57
# 2010    60
# 2011    72
# 2012    74
# 2013    76
# 2014    60
# 2015    57
# dtype: int64

# %%
df.groupby("Year")["Winning_Team"].apply(
    lambda x: (x == "FirstBatting").sum()
)
# Out:
# Year
# 2008    22
# 2009    26
# 2010    31
# 2011    32
# 2012    34
# 2013    37
# 2014    22
# 2015    32
# Name: Winning_Team, dtype: int64

# %%
df.groupby("Year")["Winning_Team"].apply(
    lambda x: (x == "Chasing").sum()
)
# Out:
# Year
# 2008    36
# 2009    30
# 2010    28
# 2011    40
# 2012    40
# 2013    37
# 2014    37
# 2015    24
# Name: Winning_Team, dtype: int64

# %%
df.groupby("Year")["Winner"].apply(
    lambda x: (x == "Match tied").sum()
)
# Out:
# Year
# 2008    0
# 2009    1
# 2010    1
# 2011    0
# 2012    0
# 2013    2
# 2014    1
# 2015    1
# Name: Winner, dtype: int64

# %%
venue_counts = df["Venue"].value_counts()

print(venue_counts)
# Out:
# Venue
# Mumbai            62
# Chennai           48
# Kolkata           47
# Bangalore         47
# Delhi             45
# Mohali            35
# Hyderabad         34
# Jaipur            33
# Pune              21
# Durban            15
# Ahmedabad         12
# Centurion         12
# Mumbai (BS)       11
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Cape Town          7
# Port Elizabeth     7
# Dubai              7
# Abu Dhabi          7
# Cuttack            7
# Sharjah            6
# Kochi              5
# Visakhapatnam      5
# Raipur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Indore             2
# Name: count, dtype: int64

# %%
df["Venue"].value_counts().head(1)
# Out:
# Venue
# Mumbai    62
# Name: count, dtype: int64

# %%
max_rr = df["Bat_First_Run_Rate"].max()
max_rr
# Out:
# 13.25

# %%
print(row[[
    "Match_Number",
    "Team_Batting_First",
    "Bat_First_Runs_Scored",
    "Bat_First_Overs_Consumed",
    "Bat_First_Run_Rate"
]])
# Out:
#      Match_Number Team_Batting_First  Bat_First_Runs_Scored  \
# 390           391          Bangalore                    106
#
#      Bat_First_Overs_Consumed  Bat_First_Run_Rate
# 390                       8.0               13.25
